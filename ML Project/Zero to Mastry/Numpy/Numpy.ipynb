# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.plot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig,ax = plt.subplots()

# %%
x = [1,2,3,4,5]
y = [11,22,33,44,55]

# %%
fig,ax = plt.subplots(figsize = (10,10))
ax.plot(x,y)
plt.title('Simple Plot')
plt.xlabel('age')
plt.ylabel('Income')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df = pd.DataFrame(data = {'Fruits': ['Orange','Apple','Mangos'],'Quantity':[ 100,150,180],'Price': [200,300,150]})

# %%
df
# Out:
#    Fruits  Quantity  Price
# 0  Orange       100    200
# 1   Apple       150    300
# 2  Mangos       180    150

# %%
fig,ax = plt.subplots(figsize = (5,5))
ax.scatter('Price','Quantity')
